# %% [markdown]
# # Proje 2
#
# Netflix Veri Analizi

# %%
import pandas as pd
import numpy as np
import csv
import matplotlib.pyplot as plt
import seaborn as sys

# %%
df = pd.read_csv('NetflixOriginals.csv', encoding="ISO-8859-1")
df
# Out:
#                                            Title                  Genre  \
# 0                                Enter the Anime            Documentary
# 1                                    Dark Forces               Thriller
# 2                                        The App  Science fiction/Drama
# 3                                 The Open House        Horror thriller
# 4                                    Kaali Khuhi                Mystery
# ..                                           ...                    ...
# 579        Taylor Swift: Reputation Stadium Tour           Concert Film
# 580  Winter on Fire: Ukraine's Fight for Freedom            Documentary
# 581                      Springsteen on Broadway           One-man show
# 582    Emicida: AmarElo - It's All For Yesterday            Documentary
# 583     David Attenborough: A Life on Our Planet            Documentary
#
#               Premiere  Runtime  IMDB Score                  Language
# ...

# %% [markdown]
# Veri setine göre uzun soluklu filmler hangi dilde oluşturulmuştur? Görselleştirme yapınız.

# %%
plt.figure(figsize=(50,50))
sys.barplot(x = "Language" ,y = "Runtime",data=df)
plt.show()

# %% [markdown]
# 2019 Ocak ile 2020 Haziran tarihleri arasında 'Documentary' türünde çekilmiş filmlerin IMDB değerlerini bulup görselleştiriniz.

# %%
dc_films= df[(df["Genre"] == "Documentary") & (pd.to_datetime(df["Premiere"]) >= pd.to_datetime('2019-01-01')) & (pd.to_datetime(df["Premiere"]) <= pd.to_datetime('2020-06-30'))]
dc_films
# Out:
#                                                  Title        Genre  \
# 0                                      Enter the Anime  Documentary
# 15                                      After the Raid  Documentary
# 20                   Hello Privilege. It's Me, Chelsea  Documentary
# 30                                         After Maria  Documentary
# 111                               Ghosts of Sugar Land  Documentary
# 151                                           One Take  Documentary
# 263                             A Tale of Two Kitchens  Documentary
# 286                       The Legend of Cocaine Island  Documentary
# 290                   Travis Scott: Look Mom I Can Fly  Documentary
# 295                                            Birders  Documentary
# 303           Murder to Mercy: The Cyntoia Brown Story  Documentary
# 320                                     A 3 Minute Hug  Documentary
# 324          Antoine Griezmann: The Making of a Legend  Documentary
# ...

# %%
plt.figure(figsize=(40,50))
sys.barplot( x = "IMDB Score", y="Title",data=dc_films)

# %% [markdown]
# İngilizce çekilen filmler içerisinde hangi tür en yüksek IMDB puanına sahiptir?

# %%
higest_imdb_dt=df[df["Language"]=="English"].sort_values(by="IMDB Score")
higest_imdb=higest_imdb_dt["Genre"].values[0]
higest_imdb
# Out:
# 'Horror thriller'

# %% [markdown]
# 'Hindi' Dilinde çekilmiş olan filmlerin ortalama 'runtime' suresi nedir?

# %%
hindi_runtime = df[df["Language"] == "Hindi"]["Runtime"].mean()
hindi_runtime
# Out:
# 115.78787878787878

# %% [markdown]
# 'Genre' Sütunu kaç kategoriye sahiptir ve bu kategoriler nelerdir? Görselleştirerek ifade ediniz.

# %%
len(df["Genre"].value_counts())
# Out:
# 115

# %%
for i in df["Genre"].unique():
    print(i)
# Out:
# Documentary
# Thriller
# Science fiction/Drama
# Horror thriller
# Mystery
# Action
# Comedy
# Heist film/Thriller
# Musical/Western/Fantasy
# Drama
# Romantic comedy
# Action comedy
# Horror anthology
# Political thriller
# Superhero-Comedy
# Horror
# Romance drama
# Anime / Short
# Superhero
# Heist
# Western
# Animation/Superhero
# Family film
# Action-thriller
# Teen comedy-drama
# Romantic drama
# Animation
# Aftershow / Interview
# Christmas musical
# Science fiction adventure
# Science fiction
# Variety show
# Comedy-drama
# Comedy/Fantasy/Family
# Supernatural drama
# Action/Comedy
# Action/Science fiction
# Romantic teenage drama
# Comedy / Musical
# Musical
# Science fiction/Mystery
# Crime drama
# Psychological thriller drama
# Adventure/Comedy
# Black comedy
# Romance
# Horror comedy
# Christian musical
# Romantic teen drama
# Family
# Dark comedy
# Comedy horror
# Psychological thriller
# Biopic
# Science fiction/Thriller
# Mockumentary
# Satire
# One-man show
# ...

# %%
plt.figure(figsize=(40,40))
sys.barplot(x = df["Genre"].value_counts(), y = df["Genre"].unique() ,)
plt.show()

# %% [markdown]
# Veri setinde bulunan filmlerde en çok kullanılan 3 dili bulunuz.

# %%
higest_lang=df["Language"].value_counts().sort_values(ascending=False)
higest_lang[0:3]
# Out:
# English    401
# Hindi       33
# Spanish     31
# Name: Language, dtype: int64

# %% [markdown]
# IMDB puanı en yüksek olan ilk 10 film hangileridir?

# %%
higest_lang=df.sort_values(by="IMDB Score", ascending=False)
higest_lang[0:10]
# Out:
#                                            Title  \
# 583     David Attenborough: A Life on Our Planet
# 582    Emicida: AmarElo - It's All For Yesterday
# 581                      Springsteen on Broadway
# 580  Winter on Fire: Ukraine's Fight for Freedom
# 579        Taylor Swift: Reputation Stadium Tour
# 578   Ben Platt: Live from Radio City Music Hall
# 577                       Dancing with the Birds
# 576                      Cuba and the Cameraman
# 573                                        Klaus
# 571                                         13th
#
#                                     Genre           Premiere  Runtime  \
# 583                           Documentary    October 4, 2020       83
# 582                           Documentary   December 8, 2020       89
# 581                          One-man show  December 16, 2018      153
# 580                           Documentary    October 9, 2015       91
# 579                          Concert Film  December 31, 2018      125
# ...

# %% [markdown]
# IMDB puanı ile 'Runtime' arasında nasıl bir korelasyon vardır? İnceleyip görselleştiriniz.

# %%
correlation = df['Runtime'].corr(df['IMDB Score'])
correlation
# Out:
# -0.04089629142078858

# %%
sns.jointplot( x=df["Runtime"], y=df["IMDB Score"], data=df)
plt.show()

# %% [markdown]
# IMDB Puanı en yüksek olan ilk 10 'Genre' hangileridir? Görselleştiriniz.

# %%
highest_imdb_genre= df.groupby('Genre', as_index=False)['IMDB Score'].mean().sort_values(by = "IMDB Score", ascending = False)[0:10]
highest_imdb_genre
# Out:
#                                    Genre  IMDB Score
# 17  Animation/Christmas/Comedy/Adventure    8.200000
# 70                       Musical / Short    7.700000
# 40                          Concert Film    7.633333
# 24                 Anthology/Dark comedy    7.600000
# 15           Animation / Science Fiction    7.500000
# 66                             Making-of    7.450000
# 3                       Action-adventure    7.300000
# 58                      Historical drama    7.200000
# 39            Coming-of-age comedy-drama    7.200000
# 48                          Drama-Comedy    7.200000

# %%
sns.barplot(y=highest_imdb_genre["Genre"],x=highest_imdb_genre["IMDB Score"])

# %% [markdown]
# 'Runtime' değeri en yüksek olan ilk 10 film hangileridir? Görselleştiriniz.

# %%
first_10_runtime=df.sort_values(by="Runtime",ascending=False)[0:10]
first_10_runtime
# Out:
#                                Title                  Genre  \
# 561                     The Irishman            Crime drama
# 328                      Da 5 Bloods              War drama
# 581          Springsteen on Broadway           One-man show
# 247                         Citation                  Drama
# 284               The Forest of Love                  Drama
# 509                   Raat Akeli Hai               Thriller
# 7    The Last Days of American Crime    Heist film/Thriller
# 543                             Ludo  Anthology/Dark comedy
# 194                 Army of the Dead           Zombie/Heist
# 5                              Drive                 Action
#
#               Premiere  Runtime  IMDB Score  Language
# 561  November 27, 2019      209         7.8   English
# 328      June 12, 2020      155         6.5   English
# 581  December 16, 2018      153         8.5   English
# 247   November 6, 2020      151         6.2   English
# ...

# %%
sns.distplot( x=first_10_runtime["Runtime"])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Hangi yılda en fazla film yayımlanmıştır? Görselleştiriniz.

# %%
by_year=pd.to_datetime(df["Premiere"]).dt.year.value_counts().sort_values(ascending=False)
by_year.keys()[0]
# Out:
# 2020

# %%
sns.barplot(x=by_year.keys(), y=by_year.values)

# %% [markdown]
# Hangi dilde yayımlanan filmler en düşük ortalama IMBD puanına sahiptir? Görselleştiriniz.

# %%
lower_imdb_lang= df.groupby('Language', as_index=False)['IMDB Score'].mean().sort_values(by = "IMDB Score")
lower_imdb_lang.head(1)
# Out:
#    Language  IMDB Score
# 24    Malay         4.2

# %%
plt.figure(figsize=(50,50))
sns.barplot(y=lower_imdb_lang["Language"],x=lower_imdb_lang["IMDB Score"])

# %% [markdown]
# Hangi yılın toplam "runtime" süresi en fazladır?

# %%
runtime_by_year = df
runtime_by_year["Year"] = pd.to_datetime(df["Premiere"]).dt.year
runtime_year=runtime_by_year.groupby("Year", as_index=False)['Runtime'].sum().sort_values(by = "Runtime", ascending = False)
runtime_year.head(1)
# Out:
#    Year  Runtime
# 6  2020    17384

# %% [markdown]
# Her bir dilin en fazla kullanıldığı "Genre" nedir?

# %%
genre_lang=pd.pivot_table(df, values='Title', index=['Language',"Genre"], aggfunc='count').reset_index().sort_values(by='Title',ascending=False)
genre_lang
# Out:
#     Language                      Genre  Title
# 44   English                Documentary    120
# 45   English                      Drama     35
# 32   English                     Comedy     30
# 76   English            Romantic comedy     27
# 96   English                   Thriller     14
# ..       ...                        ...    ...
# 81   English                     Satire      1
# 83   English  Science fiction adventure      1
# 84   English     Science fiction/Action      1
# 86   English    Science fiction/Mystery      1
# 203  Turkish                    Romance      1
#
# [204 rows x 3 columns]
